# %% [markdown]
# # Image Operations
#
# **Objective:** To provide sample code for displaying and editing images.

# %%
import os, sys
import pandas as PD

# %%
MODULE_PATH = os.path.dirname(os.getcwd())
DATA_PATH = os.path.join(MODULE_PATH, 'data')
LOGIC_PATH = os.path.join(MODULE_PATH, 'logic')
sys.path.append(LOGIC_PATH)
print(MODULE_PATH)
# Out:
# C:\Documents\Code\OpenStack\Current\MediaManager\codebase\base_module

# %%
#import cv2 as CV

# %%
# %load_ext autoreload
# %autoreload 2
from IPython.core.interactiveshell import InteractiveShell
InteractiveShell.ast_node_interactivity = 'all'
import IPython.display as DS 
from ipywidgets import IntProgress
from IPython.display import clear_output

# %%
# easy display 

imagePath = os.path.join(DATA_PATH, 'lego_set.jpg')
DS.Image(filename=imagePath, width=400)

# %%
# display with opencv

imageCv = CV.imread(imagePath, CV.IMREAD_COLOR)
imageCv = CV.imencode('.png', imageCv)[1]
DS.Image(imageCv, width=350)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-6-f2b5c79dc793> in <module>
#       1 # display with opencv
#       2
# ----> 3 imageCv = CV.imread(imagePath, CV.IMREAD_COLOR)
#       4 imageCv = CV.imencode('.png', imageCv)[1]
#       5 DS.Image(imageCv, width=350)
#
# NameError: name 'CV' is not defined
