# %% [markdown]
# # Artists from Google Sheet
#
# **Objective:** Transfer data from old google sheet fction tab into new database.

# %%
import os, sys, json
import pandas as PD
import numpy as NP

# %%
MODULE_PATH = os.path.dirname(os.getcwd())
DATA_PATH = os.path.join(MODULE_PATH, 'data')
LOGIC_PATH = os.path.join(MODULE_PATH, 'logic')
sys.path.append(LOGIC_PATH)
print(MODULE_PATH)
# Out:
# C:\Documents\Code\OpenStack\Current\MediaManager\codebase\pictures_manager

# %%
import sqlalchemy as SQL
import database_helper as DB
print([x for x in dir(DB) if '_' not in x and len(x) > 8])
dbPath = os.path.join(DATA_PATH, 'fiction.db')
meta, engine = DB.openConnection(dbPath)
# Out:
# ['openConnection']
# sqlite:///C:\Documents\Code\OpenStack\Current\MediaManager\codebase\pictures_manager\data\fiction.db

# %%
# %load_ext autoreload
# %autoreload 2
from IPython.core.interactiveshell import InteractiveShell
InteractiveShell.ast_node_interactivity = 'all'
import IPython.display as DS 
from ipywidgets import IntProgress

# %% [markdown]
# ### Add Sheet Data

# %%
artistTb = meta.tables.get('ArtistTracker')

# %%
skipArtists = [
    {'deviantId': '000fesbra000'},       {'deviantId': '6kart'},
    {'deviantId': 'airagitt'},           {'deviantId': 'alchemaniac'},
    {'deviantId': 'alexanderexorcist'},  {'deviantId': 'airagitt'},
    {'deviantId': 'alchemaniac'},        {'deviantId': 'alexson1'},
    {'deviantId': 'allnamesinuse'},      {'deviantId': 'amanda-kihlstrom'},
    {'deviantId': 'alexruizart'},        
    {'collectionId': 'anry',         'deviantId': 'anry',         'downloaded': -1},
    {'deviantId': 'andreasrocha'},       {'deviantId': 'andreiaugrai'},
    {'deviantId': 'apterus'},            {'deviantId': 'art-of-geun'},
    {'deviantId': 'borjapindado'},       {'deviantId': 'brenthollowellart'},
    {'deviantId': 'brolo'},              {'deviantId': 'chichibio'},
    {'deviantId': 'crutz'},              {'deviantId': 'clonerh'},
    {'deviantId': 'byzwa-dher'},         {'deviantId': 'caisne'},
    {'deviantId': 'chaoyuanxu'},         {'deviantId': 'christophercant'},
    {'deviantId': 'cyangmou'},           {'deviantId': 'cynic-pavel'},
    {'deviantId': 'denmanrooke'},          {'deviantId': 'dzikawa'},
    {'deviantId': 'douzen'},               {'deviantId': 'edcid'},
    {'deviantId': 'ferdinandladera'},      {'deviantId': 'fragged-empire'},
    {'deviantId': 'frakkasse'},            {'deviantId': 'inagakiivan'},
    {'deviantId': 'jamesryman'},           {'deviantId': 'josephqiuart'},
    {'deviantId': 'janemere'},             {'deviantId': 'kalasketch'},
    {'deviantId': 'kcgarza'},              {'deviantId': 'kamiyamark'},
    {'deviantId': 'kuzinskiy'},            {'deviantId': 'kangjason'},
    {'deviantId': 'linweichen'},          {'deviantId': 'lukasbanas'},
    {'collectionId': 'longai',        'deviantId': 'longai',          'downloaded': -1},
    {'deviantId': 'manzanedo'},           {'deviantId': 'marschelarts'},
    {'deviantId': 'marko-djurdjevic'},    {'deviantId': 'maxbedulenko'},
    {'deviantId': 'mattdixon'},           {'deviantId': 'morfyia'},
    {'deviantId': 'nemanja-s'},           {'deviantId': 'nightblue-art'},
    {'deviantId': 'nixell'},              {'deviantId': 'operion'},    
    {'deviantId': 'pavolsvk'},            {'deviantId': 'pc-0'},
    {'deviantId': 'picolo-kun'},          {'deviantId': 'prospass'},
    {'deviantId': 'ralphhorsley'},        {'deviantId': 'rogierb'},
    {'deviantId': 'raphtor'},             {'deviantId': 'ruanjia'},
    {'deviantId': 'sangrde'},             {'deviantId': 'sensevessel'},
    {'deviantId': 'shikazan'},            {'deviantId': 'shurita'},
    {'deviantId': 'skyzocat'},            {'deviantId': 'skavenzverov'},
    {'deviantId': 'tahra'},               {'deviantId': 'thanatornyantaporn'},
    {'deviantId': 'thiago-almeida'},      {'deviantId': 'tohad'},
    {'deviantId': 'tokotewhero'},         {'deviantId': 'toshi13go'},
    {'deviantId': 'trungtinart'},         {'deviantId': 'tomasbj'},
    {'deviantId': 'tentaclesandteeth'},    {'deviantId': 'wildweasel339'},
    {'collectionId': 'wen.m',       'deviantId': 'wen-m',            'downloaded': 1100},
    {'deviantId': 'wizyakuza'},            {'deviantId': 'zhangqipeng'},
    {'deviantId': 'zippo514'},             {'deviantId': 'zoppy'},
    {'deviantId': 'zychoart'},            {'deviantId': 'vaejoun'},
    {'deviantId': 'xiataptara'},
]

for r in skipArtists:
    r['artistType'] = 'canvas'
    r['status'] = 'skip'

for r in skipArtists:
    try:
        result = SQL.insert(artistTb).values(r).execute()
    except Exception as ex:
        pass
        #print(f"error: {r['deviantId']}")

# %%
downloadedArtists = [
    {'collectionId': 'a.miller',      'deviantId': 'aaronmiller',    'downloaded': 690},
    {'collectionId': 'admirawijaya',  'deviantId': 'admirawijaya',   'downloaded': 250},
    {'collectionId': 'agnidevi',      'deviantId': 'agnidevi',       'downloaded': 140},
    {'collectionId': 'negrea',        'deviantId': 'alexnegrea',     'downloaded': None},
    {'collectionId': 'ameba',         'deviantId': 'ameeeeba',       'downloaded': 120},
    {'collectionId': 'algen.pf',      'deviantId': 'algenpfleger',   'downloaded': 340},
    {'collectionId': 'andantonius',     'deviantId': 'andantonius',   'downloaded': 290},
    {'collectionId': 'andead',        'deviantId': 'andead',          'downloaded': 140},
    {'collectionId': 'laura.sava',    'deviantId': 'anotherwanderer', 'downloaded': 310},
    {'collectionId': 'arcipello',      'deviantId': 'arcipello',      'downloaded': 180},
    {'collectionId': 'armandeo',      'deviantId': 'armandeo64',      'downloaded': 90},
    {'collectionId': 'artgerm',       'deviantId': 'artgerm',         'downloaded': 550},
    {'collectionId': 'arvalis',       'deviantId': 'arvalis',         'downloaded': 320},
    {'collectionId': 'azaggon',       'deviantId': 'azaggon',        'downloaded': 90},
    {'collectionId': 'baklaher',      'deviantId': 'baklaher',       'downloaded': 100},
    {'collectionId': 'bob.kehl',      'deviantId': 'bobkehl',        'downloaded': 110},
    {'collectionId': 'boco',          'deviantId': 'boc0',           'downloaded': -1},
    {'collectionId': 'bn.syme',       'deviantId': 'bryansyme',      'downloaded': -1},
    {'collectionId': 'byakko',         'deviantId': 'byakko-kun',    'downloaded': -1},
    {'collectionId': 'charro',        'deviantId': 'charro-art',     'downloaded': -1},
    {'collectionId': 'chase.stone',     'deviantId': 'chasestone',   'downloaded': -1},
    {'collectionId': 'candra',        'deviantId': 'candra',         'downloaded': 2390},
    {'collectionId': 'chris.cold',     'deviantId': 'chriscold',     'downloaded': -1},
    {'collectionId': 'centeno',       'deviantId': 'cjcenteno',      'downloaded': -1},
    {'collectionId': 'ct.cearley',     'deviantId': 'clintcearley',  'downloaded': -1},
    {'collectionId': 'concept.ah',     'deviantId': 'concept-art-house', 'downloaded': -1},
    {'collectionId': 'cn.burke',       'deviantId': 'conorburkeart',  'downloaded': -1},
    {'collectionId': 'crow.god',       'deviantId': 'crow-god',       'downloaded': -1},
    {'collectionId': 'cryptcrawler',   'deviantId': 'cryptcrawler',    'downloaded': 120},
    {'collectionId': 'dark.geo',      'deviantId': 'darkgeometryart', 'downloaded': -1},
    {'collectionId': 'melvin',        'deviantId': 'davesrightmind',   'downloaded': -1},
    {'collectionId': 'd.luvisi',      'deviantId': 'danluvisiart',    'downloaded': -1},
    {'collectionId': 'djahal',        'deviantId': 'djahal',          'downloaded': -1},
    {'collectionId': 'rapoza',        'deviantId': 'daverapoza',      'downloaded': -1},
    {'collectionId': 'depingo',       'deviantId': 'depingo',         'downloaded': -1},
    {'collectionId': 'dongjun',       'deviantId': 'dongjunlu',      'downloaded': -1},
    {'collectionId': 'dabana',        'deviantId': 'dabana',         'downloaded': 30},
    {'collectionId': 'draken',        'deviantId': 'draken4o',       'downloaded': 150},
    {'collectionId': 'devburmak',     'deviantId': 'devburmak',      'downloaded': -1},
    {'collectionId': 'daarken',       'deviantId': 'daarken',         'downloaded': -1},
    {'collectionId': 'fd.runtu',      'deviantId': 'fredrickruntu',   'downloaded': -1},
    {'collectionId': 'f.haircut',     'deviantId': 'friendhaircut',   'downloaded': -1},
    {'collectionId': 'firatsolhan',    'deviantId': 'firatsolhan',    'downloaded': -1},
    {'collectionId': 'flowerzzxu',     'deviantId': 'flowerzzxu',     'downloaded': 122},
    {'collectionId': 'fr.imel',       'deviantId': 'forrestimel',     'downloaded': 258},
    {'collectionId': 'estivador',     'deviantId': 'estivador',       'downloaded': 348},
    {'collectionId': 'earl.graey',     'deviantId': 'earl-graey',     'downloaded': 224},
    {'collectionId': 'ediktart',      'deviantId': 'EdiktArt',        'downloaded': 60},
    {'collectionId': 'el.grimlock',    'deviantId': 'el-grimlock',   'downloaded': -1},
    {'collectionId': 'elena.dd',      'deviantId': 'elenadudina',     'downloaded': -1},
    {'collectionId': 'exellero',      'deviantId': 'exellero',       'downloaded': -1},
    {'collectionId': 'gimaldinov',     'deviantId': 'gimaldinov',     'downloaded': -1},
    {'collectionId': 'genzoman',       'deviantId': 'genzoman',       'downloaded': -1},
    {'collectionId': 'ghostbow',       'deviantId': 'ghostbow',       'downloaded': 100},
    {'collectionId': 'guterrez',       'deviantId': 'guterrez',      'downloaded': -1},
    {'collectionId': 'grafit',        'deviantId': 'grafit-art',     'downloaded': -1},
    {'collectionId': 'gpzang',        'deviantId': 'gpzang',         'downloaded': -1},
    {'collectionId': 'grey.hues',      'deviantId': 'greyhues',      'downloaded': -1},
    {'collectionId': 'hamsterfly',     'deviantId': 'hamsterfly',    'downloaded': -1},
    {'collectionId': 'herckeim',       'deviantId': 'herckeim',       'downloaded': -1},
    {'collectionId': 'hideyoshi',     'deviantId': 'hideyoshi',      'downloaded': -1},
    {'collectionId': 'hammk',         'deviantId': 'hammk',          'downloaded': -1},
    {'collectionId': 'hellstern',     'deviantId': 'hellstern',      'downloaded': -1},
    {'collectionId': 'henning',       'deviantId': 'henning',        'downloaded': -1},
    {'collectionId': 'kieryluk',      'deviantId': 'igorkieryluk',   'downloaded': -1},
    {'collectionId': 'ilacha',        'deviantId': 'ilacha',         'downloaded': -1},
    {'collectionId': 'jiyu.kaze',     'deviantId': 'jiyu-kaze',       'downloaded': -1},
    {'collectionId': 'jh.morrow',     'deviantId': 'johnnymorrow',    'downloaded': -1},
    {'collectionId': 'jh.silva',      'deviantId': 'johnsilva',      'downloaded': -1},
    {'collectionId': 'lagerwall',     'deviantId': 'joel-lagerwall', 'downloaded': -1},
    {'collectionId': 'jn.grenier',    'deviantId': 'johangrenier',   'downloaded': -1},
    {'collectionId': 'j.sonting',     'deviantId': 'johnsonting',     'downloaded': -1},
    {'collectionId': 'kerembeyit',    'deviantId': 'kerembeyit',     'downloaded': -1},
    {'collectionId': 'kiddo_',        'deviantId': 'kiddo428',        'downloaded': -1},
    {'collectionId': 'kilrt.dev',     'deviantId': 'kilartdev',       'downloaded': -1},
    {'collectionId': 'cianjur',       'deviantId': 'kikicianjur',    'downloaded': -1},
    {'collectionId': 'lasahido',      'deviantId': 'lasahido',        'downloaded': -1},
    {'collectionId': 'setiawan',      'deviantId': 'liesetiawan',     'downloaded': 170},
    {'collectionId': 'linggar',       'deviantId': 'linggarbramanty', 'downloaded': 20},
    {'collectionId': 'luches',        'deviantId': 'luches',          'downloaded': 150},
    {'collectionId': 'lumberjackz',   'deviantId': 'lumberjackz',     'downloaded': 30},
    {'collectionId': 'ld.wakefield',   'deviantId': 'lindseywart',    'downloaded': 420},
    {'collectionId': 'styakina',      'deviantId': 'lerastyajkina',   'downloaded': -1},
    {'collectionId': 'macarious',     'deviantId': 'macarious',       'downloaded': -1},
    {'collectionId': 'mc.kuciara',     'deviantId': 'maciejkuciara',  'downloaded': -1},
    {'collectionId': 'magmasaya',     'deviantId': 'magmasaya',       'downloaded': 40},
    {'collectionId': 'mc.medeiros',    'deviantId': 'marcelamedeiros-arts', 'downloaded': -1},
    {'collectionId': 'michalivan',     'deviantId': 'michalivan',     'downloaded': -1},
    {'collectionId': 'mr.jack',        'deviantId': 'mr--jack',        'downloaded': -1},
    {'collectionId': 'moonxels',      'deviantId': 'moonxels',         'downloaded': 210},
    {'collectionId': 'moonskin',      'deviantId': 'moonskinned',      'downloaded': -1},
    {'collectionId': 'magic.navi',     'deviantId': 'magicnaanavi',    'downloaded': -1},
    {'collectionId': 'm.kutsche',     'deviantId': 'michaelkutsche',   'downloaded': -1},
    {'collectionId': 'majentta',      'deviantId': 'Majentta',         'downloaded': -1},
    {'collectionId': 'malverro',      'deviantId': 'malverro',         'downloaded': -1},
    {'collectionId': 'namesjames',     'deviantId': 'namesjames',      'downloaded': -1},
    {'collectionId': 'nisachar',      'deviantId': 'nisachar',         'downloaded': -1},
    {'collectionId': 'neisbeis',      'deviantId': 'neisbeis',         'downloaded': -1},
    {'collectionId': 'nh.bradley',     'deviantId': 'noahbradley',     'downloaded': -1},
    {'collectionId': 'natsuki',       'deviantId': 'natsuki-3',        'downloaded': -1},
    {'collectionId': 'nebezial',      'deviantId': 'nebezial',         'downloaded': 810},
    {'collectionId': 'nukerooster',    'deviantId': 'nukerooster',     'downloaded': 590},
    {'collectionId': 'omen_',         'deviantId': 'omen2501',          'downloaded': 111},
    {'collectionId': 'pao',           'deviantId': 'paooo',             'downloaded': 253},
    {'collectionId': 'preilly',       'deviantId': 'preilly',           'downloaded': 123},
    {'collectionId': 'pindurski',     'deviantId': 'pindurski',         'downloaded': 72},
    {'collectionId': 'pm.bacher',     'deviantId': 'petemohrbacher',    'downloaded': 100},
    {'collectionId': 'rahll',         'deviantId': 'rahll',             'downloaded': 100},
    {'collectionId': 'rp.lacoste',     'deviantId': 'raphael-lacoste',  'downloaded': 114},
    {'collectionId': 'ratatrampa_',    'deviantId': 'ratatrampa87',     'downloaded': -1},
    {'collectionId': 'reykat',        'deviantId': 'reykat',            'downloaded': -1},
    {'collectionId': 'sandara',       'deviantId': 'sandara',           'downloaded': -1},
    {'collectionId': 'ninjanub',      'deviantId': 'superninjanub',     'downloaded': -1},
    {'collectionId': 'mckinnon',      'deviantId': 'sebmckinnon',       'downloaded': -1},
    {'collectionId': 'scebiqu',        'deviantId': 'scebiqu',          'downloaded': -1},
    {'collectionId': 'spiralmagus',    'deviantId': 'spiralmagus',      'downloaded': -1},
    {'collectionId': 'tetramera',     'deviantId': 'tetramera',         'downloaded': -1},
    {'collectionId': 'trident.ps',     'deviantId': 'trident-poseidon',  'downloaded': 250},
    {'collectionId': 'first.angel',    'deviantId': 'thefirstangel',     'downloaded': -1},
    {'collectionId': 'takeda',        'deviantId': 'takeda11',          'downloaded': -1},
    {'collectionId': 'thienbao',      'deviantId': 'thienbao',          'downloaded': -1},
    {'collectionId': 'tamplier',      'deviantId': 'tamplierpainter',    'downloaded': -1},
    {'collectionId': 'ukitakumuki',   'deviantId': 'ukitakumuki',       'downloaded': -1},
    {'collectionId': 'vegasmike',     'deviantId': 'vegasmike',         'downloaded': -1},
    {'collectionId': 'velinov',       'deviantId': 'velinov',           'downloaded': -1},
    {'collectionId': 'wen.jr',        'deviantId': 'wen-jr',            'downloaded': -1},
    {'collectionId': 'wisnutan',      'deviantId': 'wisnutan',          'downloaded': 65},
    {'collectionId': 'wraithdt',     'deviantId': 'wraithdt',           'downloaded': 165},
    {'collectionId': 'wreckonning',   'deviantId': 'wreckonning',       'downloaded': 59},
    {'collectionId': 'yangqi_',       'deviantId': 'yangqi917',         'downloaded': 80},
    {'collectionId': 'koroglu',       'deviantId': 'yigitkoroglu',      'downloaded': 170},
    {'collectionId': 'yinyuming',     'deviantId': 'yinyuming',          'downloaded': 60},
    {'collectionId': 'zoonoid',       'deviantId': 'zoonoid',           'downloaded': 98},
    {'collectionId': 'zezhou',        'deviantId': 'zezhou',            'downloaded': 140},
]

for r in downloadedArtists:
    r['artistType'] = 'canvas'
    r['status'] = '2020-12'

for r in downloadedArtists:
    try:
        result = SQL.insert(artistTb).values(r).execute()
    except Exception as ex:
        pass
        #print(f"error: {r['deviantId']}")

# %%
favouriteChecked = [
    {'collectionId': '_grzes',   'deviantId': '88grzes',      'downloaded': 240},
    {'collectionId': 'abremson', 'deviantId': 'abremson',     'downloaded': 150},
    {'collectionId': 'garner',   'deviantId': 'alexgarner',   'downloaded': 150},
    {'collectionId': 'amnis_',   'deviantId': 'amnis406',     'downloaded': 270},
    {'collectionId': 'wallin',   'deviantId': 'andreewallin', 'downloaded': 130},
    {'collectionId': 'art.deep', 'deviantId': 'ArtDeepMind',  'downloaded': 600},
]

for r in favouriteChecked:
    r['artistType'] = 'canvas'
    r['status'] = '2020-12'
    r['favourites'] = True

for r in favouriteChecked:
    try:
        result = SQL.insert(artistTb).values(r).execute()
    except Exception as ex:
        pass
        print(f"error: {r['deviantId']}")

# %% [markdown]
# ### Check Results

# %%
statement = SQL.select(artistTb)
results = statement.execute()
resultsDx = [dict(x) for x in results]

artistDf = PD.DataFrame(resultsDx)
artistDf.head()
artistDf.shape
# Out:
#    id collectionId          deviantId artistType status  favourites collected  \
# 0   1        no-id       000fesbra000     canvas   skip       False      None
# 1   2        no-id              6kart     canvas   skip       False      None
# 2   3        no-id           airagitt     canvas   skip       False      None
# 3   4        no-id        alchemaniac     canvas   skip       False      None
# 4   5        no-id  alexanderexorcist     canvas   skip       False      None
#
#    downloaded
# 0         NaN
# 1         NaN
# 2         NaN
# 3         NaN
# 4         NaN
# (227, 8)

# %%
skipDf = artistDf[artistDf['status']=='skip']
skipDf.head()
skipDf.shape
# Out:
#    id collectionId          deviantId artistType status  favourites collected  \
# 0   1        no-id       000fesbra000     canvas   skip       False      None
# 1   2        no-id              6kart     canvas   skip       False      None
# 2   3        no-id           airagitt     canvas   skip       False      None
# 3   4        no-id        alchemaniac     canvas   skip       False      None
# 4   5        no-id  alexanderexorcist     canvas   skip       False      None
#
#    downloaded
# 0         NaN
# 1         NaN
# 2         NaN
# 3         NaN
# 4         NaN
# (87, 8)

# %%
downloadDf = artistDf[artistDf['status']!='skip']
downloadDf.head()
downloadDf.shape
# Out:
#     id  collectionId     deviantId artistType   status  favourites collected  \
# 87  88      a.miller   aaronmiller     canvas  2020-12       False      None
# 88  89  admirawijaya  admirawijaya     canvas  2020-12       False      None
# 89  90      agnidevi      agnidevi     canvas  2020-12       False      None
# 90  91        negrea    alexnegrea     canvas  2020-12       False      None
# 91  92         ameba      ameeeeba     canvas  2020-12       False      None
#
#     downloaded
# 87       690.0
# 88       250.0
# 89       140.0
# 90         0.0
# 91       120.0
# (140, 8)

# %%
downloadDf = artistDf[(artistDf['downloaded']!=-1) & (artistDf['status']!='skip')]
downloadDf.head()
downloadDf.shape
# Out:
#     id  collectionId     deviantId artistType   status  favourites collected  \
# 87  88      a.miller   aaronmiller     canvas  2020-12       False      None
# 88  89  admirawijaya  admirawijaya     canvas  2020-12       False      None
# 89  90      agnidevi      agnidevi     canvas  2020-12       False      None
# 90  91        negrea    alexnegrea     canvas  2020-12       False      None
# 91  92         ameba      ameeeeba     canvas  2020-12       False      None
#
#     downloaded
# 87       690.0
# 88       250.0
# 89       140.0
# 90         0.0
# 91       120.0
# (57, 8)
