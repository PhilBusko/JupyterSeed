# %% [markdown]
# # Artists from Google Sheet
#
# **Objective:** Transfer data from old google sheet cosplay tab into new database.

# %%
import os, sys, json
import pandas as PD
import numpy as NP

# %%
MODULE_PATH = os.path.dirname(os.getcwd())
DATA_PATH = os.path.join(MODULE_PATH, 'data')
LOGIC_PATH = os.path.join(MODULE_PATH, 'logic')
sys.path.append(LOGIC_PATH)
print(MODULE_PATH)
# Out:
# C:\Documents\Code\OpenStack\Current\MediaManager\codebase\pictures_manager

# %%
import sqlalchemy as SQL
import database_helper as DB
print([x for x in dir(DB) if '_' not in x and len(x) > 8])
dbPath = os.path.join(DATA_PATH, 'fiction.db')
meta, engine = DB.openConnection(dbPath)
# Out:
# ['openConnection']
# sqlite:///C:\Documents\Code\OpenStack\Current\MediaManager\codebase\pictures_manager\data\fiction.db

# %%
# %load_ext autoreload
# %autoreload 2
from IPython.core.interactiveshell import InteractiveShell
InteractiveShell.ast_node_interactivity = 'all'
import IPython.display as DS 
from ipywidgets import IntProgress

# %% [markdown]
# ### Add Sheet Data

# %%
artistTb = meta.tables.get('ArtistTracker')

# %%
skipArtists = [
    {'deviantId': 'alyonheart'},       {'deviantId': 'kuro16180339'},
    {'deviantId': 'andrewhitc'},       {'deviantId': 'milliganvick'},
    {'deviantId': 'wan-mei'},       
]

for r in skipArtists:
    r['artistType'] = 'cosplay'
    r['status'] = 'photographer'

for r in skipArtists:
    try:
        result = SQL.insert(artistTb).values(r).execute()
    except Exception as ex:
        pass
        #print(f"error: {r['deviantId']}")

# %%
downloadedArtists = [
    {'collectionId': '_ryo',            'deviantId': '35ryo',              'downloaded': -1},
    {'collectionId': 'alex.reiss',      'deviantId': 'alexreiss',          'downloaded': -1},
    {'collectionId': 'alice.cosland',   'deviantId': 'aliceincosplayland',    'downloaded': -1},
    {'collectionId': 'angela.bz',       'deviantId': 'angelabermudez',    'downloaded': -1},
    {'collectionId': 'astarohime',      'deviantId': 'astarohime',        'downloaded': -1},
    {'collectionId': 'astellecia',      'deviantId': 'astellecia',        'downloaded': -1},
    {'collectionId': 'avine',           'deviantId': 'avine',             'downloaded': -1},
    {'collectionId': 'al.tabbitha',     'deviantId': 'alysontabbitha',    'downloaded': -1},
    {'collectionId': 'an.orihara',      'deviantId': 'alienorihara',      'downloaded': -1},
    {'collectionId': 'adelhaid',        'deviantId': 'adelhaid',          'downloaded': -1},
    {'collectionId': 'alberti',         'deviantId': 'alberti',           'downloaded': -1},
    {'collectionId': 'bellatrix.d',     'deviantId': 'bellatrixaiden',      'downloaded': -1},
    {'collectionId': 'bm.alodia',       'deviantId': 'blackmagealodia',      'downloaded': -1},
    {'collectionId': 'c.graziano',       'deviantId': 'CrystalGraziano',    'downloaded': -1},
    {'collectionId': 'colnaghi',        'deviantId': 'pamelacolnaghi',      'downloaded': -1},
    {'collectionId': 'cherryb',         'deviantId': 'cherryb-cosplay',      'downloaded': -1},
    {'collectionId': 'chinhy.sou',       'deviantId': 'chinhy-sou',       'downloaded': -1},
    {'collectionId': 'dawn.rt',         'deviantId': 'dawnarts',          'downloaded': -1},
    {'collectionId': 'ekiholic',       'deviantId': 'ekiholic',           'downloaded': -1},
    {'collectionId': 'enjinight',       'deviantId': 'enjinight',         'downloaded': -1},
    {'collectionId': 'ennfranco',       'deviantId': 'ennfranco',         'downloaded': -1},
    {'collectionId': 'fenix.ft',       'deviantId': 'fenixfatalist',      'downloaded': -1},
    {'collectionId': 'frosel',         'deviantId': 'frosel',             'downloaded': -1},
    {'collectionId': 'fausto.tn',       'deviantId': 'fausto-the-endless',      'downloaded': -1},
    {'collectionId': 'firiless',       'deviantId': 'firiless',           'downloaded': -1},
    {'collectionId': 'gesha.pt',       'deviantId': 'geshapetrovich',      'downloaded': -1},
    {'collectionId': 'heza.chan',       'deviantId': 'heza.chan',          'downloaded': -1},
    {'collectionId': 'indie.vamp',      'deviantId': 'indie-vampire',      'downloaded': -1},
    {'collectionId': 'keru',            'deviantId': 'keruuu',            'downloaded': -1},
    {'collectionId': 'kiaraberry',      'deviantId': 'KiaraBerry',        'downloaded': -1},
    {'collectionId': 'kicka',           'deviantId': 'kickacosplay',      'downloaded': -1},
    {'collectionId': 'kimon',           'deviantId': 'kimontherocks',      'downloaded': -1},
    {'collectionId': 'kilory',         'deviantId': 'kilory',             'downloaded': -1},
    {'collectionId': 'lana.temi',       'deviantId': 'lanatemirova',       'downloaded': -1},
    {'collectionId': 'lucky.strike',    'deviantId': 'LuckyStrikeCosplay',      'downloaded': -1},
    {'collectionId': 'lk.yuna',        'deviantId': 'lil-krn-yuna',        'downloaded': -1},
    {'collectionId': 'lalaax',         'deviantId': 'lalaax',              'downloaded': -1},
    {'collectionId': 'lykanka',        'deviantId': 'lykanka',             'downloaded': -1},
    {'collectionId': 'magmasaya',       'deviantId': 'magmasaya',          'downloaded': -1},
    {'collectionId': 'maywolf',         'deviantId': 'maywolf23',            'downloaded': 231},
    {'collectionId': 'misaki.sai',      'deviantId': 'misaki-sai',          'downloaded': -1},
    {'collectionId': 'momo.chan',       'deviantId': 'momo-chan59',         'downloaded': -1},
    {'collectionId': 'mrs.gnob',        'deviantId': 'mrsgnob',             'downloaded': -1},
    {'collectionId': 'mercurygin',       'deviantId': 'mercurygin',        'downloaded': 600},
    {'collectionId': 'malinda',         'deviantId': 'malindachan',        'downloaded': 574},
    {'collectionId': 'narga.lf',        'deviantId': 'narga-lifestream',      'downloaded': -1},
    {'collectionId': 'nelliel',         'deviantId': 'nelliel',            'downloaded': -1},
    {'collectionId': 'niamash',         'deviantId': 'niamash',             'downloaded': -1},
    {'collectionId': 'nomokis',         'deviantId': 'nomokis',             'downloaded': -1},
    {'collectionId': 'onkami',          'deviantId': 'onkami',              'downloaded': -1},
    {'collectionId': 'rainbow.ms',       'deviantId': 'rainbowmissy',      'downloaded': -1},
    {'collectionId': 'rei.doll',        'deviantId': 'rei-doll',              'downloaded': -1},
    {'collectionId': 'riddle',          'deviantId': 'riddle1',               'downloaded': -1},
    {'collectionId': 'rufflebutt',       'deviantId': 'RuffleButtCosplay',      'downloaded': -1},
    {'collectionId': 'ryoko.demon',       'deviantId': 'ryoko-demon',      'downloaded': -1},
    {'collectionId': 'riharu',          'deviantId': 'riharusame',          'downloaded': -1},
    {'collectionId': 'shoko',           'deviantId': 'Shoko-Cosplay',      'downloaded': 782},
    {'collectionId': 'sunnii.d',         'deviantId': 'sunnii-d',          'downloaded': -1},
    {'collectionId': 'toniji',           'deviantId': 'Toniji-Arts',        'downloaded': 140},
    {'collectionId': 'twinfools',       'deviantId': 'twinfools',          'downloaded': -1},
    {'collectionId': 'uzuchi',           'deviantId': 'uzuchi',             'downloaded': -1},
    {'collectionId': 'vamp.beauty',      'deviantId': 'VampBeauty',         'downloaded': -1},
    {'collectionId': 'vasya.chan',       'deviantId': 'vasya-chan',         'downloaded': -1},
    {'collectionId': 'verisa',          'deviantId': 'ver1sa',               'downloaded': -1},
    {'collectionId': 'yoru_',           'deviantId': 'yoru0704',           'downloaded': -1},
    {'collectionId': 'yuki.gb',         'deviantId': 'yukigodbless',       'downloaded': -1},
    {'collectionId': 'yaya.han',       'deviantId': 'yayacosplay',          'downloaded': 335},
    {'collectionId': 'zyunka.mk',       'deviantId': 'zyunkamukhina',      'downloaded': -1},
]

for r in downloadedArtists:
    r['artistType'] = 'cosplay'
    r['status'] = '2020-12'

for r in downloadedArtists:
    try:
        result = SQL.insert(artistTb).values(r).execute()
    except Exception as ex:
        pass
        #print(f"error: {r['deviantId']}")

# %% [markdown]
# ### Check Results

# %%
statement = SQL.select(artistTb).where(artistTb.c.artistType=='cosplay')
results = statement.execute()
resultsDx = [dict(x) for x in results]

artistDf = PD.DataFrame(resultsDx)
artistDf.head()
artistDf.shape
# Out:
#     id collectionId     deviantId artistType        status  favourites  \
# 0  304        no-id    alyonheart    cosplay  photographer       False
# 1  305        no-id  kuro16180339    cosplay  photographer       False
# 2  306        no-id    andrewhitc    cosplay  photographer       False
# 3  307        no-id  milliganvick    cosplay  photographer       False
# 4  308        no-id       wan-mei    cosplay  photographer       False
#
#   collected  downloaded
# 0      None         NaN
# 1      None         NaN
# 2      None         NaN
# 3      None         NaN
# 4      None         NaN
# (72, 8)

# %%
skipDf = artistDf[artistDf['status']=='photographer']
skipDf.head()
skipDf.shape
# Out:
#     id collectionId     deviantId artistType        status  favourites  \
# 0  304        no-id    alyonheart    cosplay  photographer       False
# 1  305        no-id  kuro16180339    cosplay  photographer       False
# 2  306        no-id    andrewhitc    cosplay  photographer       False
# 3  307        no-id  milliganvick    cosplay  photographer       False
# 4  308        no-id       wan-mei    cosplay  photographer       False
#
#   collected  downloaded
# 0      None         NaN
# 1      None         NaN
# 2      None         NaN
# 3      None         NaN
# 4      None         NaN
# (5, 8)

# %%
downloadDf = artistDf[artistDf['status']!='photographer']
downloadDf.head()
downloadDf.shape
# Out:
#     id   collectionId           deviantId artistType   status  favourites  \
# 5  309           _ryo               35ryo    cosplay  2020-12       False
# 6  310     alex.reiss           alexreiss    cosplay  2020-12       False
# 7  311  alice.cosland  aliceincosplayland    cosplay  2020-12       False
# 8  312      angela.bz      angelabermudez    cosplay  2020-12       False
# 9  313     astarohime          astarohime    cosplay  2020-12       False
#
#   collected  downloaded
# 5      None        -1.0
# 6      None        -1.0
# 7      None        -1.0
# 8      None        -1.0
# 9      None        -1.0
# (67, 8)

# %%
downloadDf = artistDf[(artistDf['downloaded']!=-1) & (artistDf['status']!='photographer')]
downloadDf.head()
downloadDf.shape
# Out:
#      id collectionId      deviantId artistType   status  favourites collected  \
# 43  347      maywolf      maywolf23    cosplay  2020-12       False      None
# 47  351   mercurygin     mercurygin    cosplay  2020-12       False      None
# 48  352      malinda    malindachan    cosplay  2020-12       False      None
# 60  364        shoko  Shoko-Cosplay    cosplay  2020-12       False      None
# 62  366       toniji    Toniji-Arts    cosplay  2020-12       False      None
#
#     downloaded
# 43       231.0
# 47       600.0
# 48       574.0
# 60       782.0
# 62       140.0
# (6, 8)
